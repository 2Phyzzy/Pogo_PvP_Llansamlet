# %% [markdown]
# # Pogo PvP Llansamlet Score Board
#
# ### Here the data will be imported and will be analysed

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_csv("data.csv",index_col=0)

data['Total'] = data.fillna(0)['Week 1'] + data.fillna(0)['Week 2']
data
# Out:
#                  Week 1  Week 2  Total
# eLBeen                4     0.0    4.0
# 2Phyzzy               5     0.0    5.0
# SonGohan              2     0.0    2.0
# urnotjessica          2     NaN    2.0
# YMGamer               3     0.0    3.0
# Andydah1989           4     0.0    4.0
# Pellztattoos          4     0.0    4.0
# Sikh_Dynamite         3     0.0    3.0
# AdamPohl93            2     NaN    2.0
# JAMMYDODGER2012       3     0.0    3.0
# DDCraigMcD            2     0.0    2.0
# ShanaanBreadOG        1     NaN    1.0
# starcati              3     NaN    3.0
# Sarahmguy             1     0.0    1.0
# Buetye                2     0.0    2.0
# AceAries88            3     0.0    3.0
# KHabberjam            1     0.0    1.0
# mattbeer87            2     NaN    2.0
# RAYCHARLESURASS       3     0.0    3.0

# %% [markdown]
# ## Now the data will be plotted along multiple metrix

# %%
data['Week 1']
# Out:
# eLBeen             4
# 2Phyzzy            5
# SonGohan           2
# urnotjessica       2
# YMGamer            3
# Andydah1989        4
# Pellztattoos       4
# Sikh_Dynamite      3
# AdamPohl93         2
# JAMMYDODGER2012    3
# DDCraigMcD         2
# ShanaanBreadOG     1
# starcati           3
# Sarahmguy          1
# Buetye             2
# AceAries88         3
# KHabberjam         1
# mattbeer87         2
# RAYCHARLESURASS    3
# Name: Week 1, dtype: int64

# %%
data.loc['2Phyzzy']
# Out:
# Week 1    5.0
# Week 2    0.0
# Total     5.0
# Name: 2Phyzzy, dtype: float64

# %%
Names = data.index.values.tolist()

# %%
plt.figure(figsize = (10,7))

for item in Names:
    plt.plot(data.loc[item],label=item)
plt.grid()
plt.legend()
plt.show()
